# %% [markdown]
# ![spotify_logo](../img/spotify_logo.png)
#
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
# Imports
# Option 8 64KEffDW9EtZ1y2vBYgq8T

import pandas as pd
import numpy as np
import requests

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` to generate your __token__ access

# %%
# Generate token with a POST request

auth_url = 'https://accounts.spotify.com/api/token'

# %%
auth_response = requests.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()

# %%
auth_response
# Out:
# {'access_token': 'BQDlsZ1z1QB8X6rOd0N4bzZzmzEvpIePc-c0ZMVXOu5Kz30ni4JeKjVvkoYdnJKOV7gczZaLZGy0Mvj0WFHnsZcB5dz5uLl1KXjYvfDvNFRehsFyTJns',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %%
access_token = auth_response['access_token']
access_token
# Out:
# 'BQDlsZ1z1QB8X6rOd0N4bzZzmzEvpIePc-c0ZMVXOu5Kz30ni4JeKjVvkoYdnJKOV7gczZaLZGy0Mvj0WFHnsZcB5dz5uLl1KXjYvfDvNFRehsFyTJns'

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_uri` (i.e.: end-point), parameters and `headers` for your __GET__ operations

# %%
# Base end-point construction

base_url = 'https://api.spotify.com/v1/'
resource = 'artists/'

header_info = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %%
header_info
# Out:
# {'Authorization': 'Bearer BQDlsZ1z1QB8X6rOd0N4bzZzmzEvpIePc-c0ZMVXOu5Kz30ni4JeKjVvkoYdnJKOV7gczZaLZGy0Mvj0WFHnsZcB5dz5uLl1KXjYvfDvNFRehsFyTJns'}

# %% [markdown]
# ### Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need.
#
# __Here you have the different artists to start with:__
#
# - __Option 1:__ 0L8ExT028jH3ddEcZwqJJ5
#
# - __Option 2:__ 4Y7tXHSEejGu1vQ9bwDdXW
#
# - __Option 3:__ 6FBDaR13swtiWwGhX1WQsP
#
# - __Option 4:__ 0kyQwKHCZnKE7kTXkxXjrB
#
# - __Option 5:__ 2d0hyoQ5ynDBnkvAbJKORj
#
# - __Option 6:__ 3bgsNtcf5d5h9jbQbohfBK
#
# - __Option 7:__ 7mWCSSOYqm4E9mB7V4ot6S
#
# - __Option 8:__ 64KEffDW9EtZ1y2vBYgq8T
#
# - __Option 9:__ 4k1ELeJKT1ISyDv8JivPpB
#
# - __Option 10:__ 4Z8W4fKeB5YxbusRsdQVPb
#
# - __Option 11:__ 26dSoYclwsYLMAKD3tpOr4
#
# - __Option 12:__ 7y97mc3bZRFXzT2szRM4L4
#
# - __Option 13:__ 1w5Kfo2jwwIPruYS2UWh56
#
#
# > Remember to check the [Requests](https://requests.readthedocs.io/en/latest/) library docs!!!
#
# ---

# %%
# Here you can complete your endpoint URI

artist_id = '64KEffDW9EtZ1y2vBYgq8T'
related_artists = '/related-artists'
top_tracks = '/top-tracks'
country = '?country=us'

full_endpoint = base_url + resource + artist_id
full_endpoint
# Out:
# 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T'

# %%
# Start building your playlist!!!

res = requests.get(full_endpoint, headers = header_info)
res
# Out:
# <Response [200]>

# %%
type(res)
# Out:
# requests.models.Response

# %%
type(res.json())
# Out:
# dict

# %%
res_dict = res.json()
len(res_dict)
# Out:
# 10

# %%
key_list = res_dict.keys()
key_list
# Out:
# dict_keys(['external_urls', 'followers', 'genres', 'href', 'id', 'images', 'name', 'popularity', 'type', 'uri'])

# %%
for key in key_list:
    print(key, '--->' ,res_dict[key])
# Out:
# external_urls ---> {'spotify': 'https://open.spotify.com/artist/64KEffDW9EtZ1y2vBYgq8T'}
# followers ---> {'href': None, 'total': 34952243}
# genres ---> ['brostep', 'dance pop', 'edm', 'pop', 'pop dance', 'progressive electro house']
# href ---> https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T
# id ---> 64KEffDW9EtZ1y2vBYgq8T
# images ---> [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb41e4a3b8c1d45a9e49b6de21', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab6761610000517441e4a3b8c1d45a9e49b6de21', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f17841e4a3b8c1d45a9e49b6de21', 'width': 160}]
# name ---> Marshmello
# popularity ---> 85
# type ---> artist
# uri ---> spotify:artist:64KEffDW9EtZ1y2vBYgq8T

# %%
full_endpoint_01 = full_endpoint + related_artists
print(full_endpoint)

res_01 = requests.get(full_endpoint_01, headers=header_info)
res_01
# Out:
# https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T
# <Response [200]>

# %%
res_01_dict = res_01.json()
res_01_dict
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp'},
#    'followers': {'href': None, 'total': 20003183},
#    'genres': ['dance pop',
#     'edm',
#     'electropop',
#     'pop',
#     'pop dance',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp',
#    'id': '69GGBxA162lTqCwzJG5jLp',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb3c02f4fb4cc9187c488afd50',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051743c02f4fb4cc9187c488afd50',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1783c02f4fb4cc9187c488afd50',
#      'width': 160}],
#    'name': 'The Chainsmokers',
#    'popularity': 82,
#    'type': 'artist',
#    'uri': 'spotify:artist:69GGBxA162lTqCwzJG5jLp'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7DMveApC7UnC2NPfPvlHSU'},
#    'followers': {'href': None, 'total': 2159804},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'electropop',
#     'pop',
#     'pop dance',
#     'post-teen pop',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/7DMveApC7UnC2NPfPvlHSU',
#    'id': '7DMveApC7UnC2NPfPvlHSU',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb6b4a14efca7b2fd8967390be',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051746b4a14efca7b2fd8967390be',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1786b4a14efca7b2fd8967390be',
#      'width': 160}],
#    'name': 'Cheat Codes',
#    'popularity': 72,
#    'type': 'artist',
#    'uri': 'spotify:artist:7DMveApC7UnC2NPfPvlHSU'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6t1gpxYbY8OlLA7D2RiikQ'},
#    'followers': {'href': None, 'total': 610536},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'pop',
#     'pop dance',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/6t1gpxYbY8OlLA7D2RiikQ',
#    'id': '6t1gpxYbY8OlLA7D2RiikQ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eba4686c91d1b14b400725f95e',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174a4686c91d1b14b400725f95e',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178a4686c91d1b14b400725f95e',
#      'width': 160}],
#    'name': 'Loud Luxury',
#    'popularity': 72,
#    'type': 'artist',
#    'uri': 'spotify:artist:6t1gpxYbY8OlLA7D2RiikQ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6lB8vOoI4DRrrVxXwuV19c'},
#    'followers': {'href': None, 'total': 1477986},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'pop',
#     'pop dance',
#     'pop edm',
#     'swedish tropical house',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/6lB8vOoI4DRrrVxXwuV19c',
#    'id': '6lB8vOoI4DRrrVxXwuV19c',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb4ca7ccebc2f9e6c281cd6ff3',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051744ca7ccebc2f9e6c281cd6ff3',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1784ca7ccebc2f9e6c281cd6ff3',
#      'width': 160}],
#    'name': 'Mike Perry',
#    'popularity': 70,
#    'type': 'artist',
#    'uri': 'spotify:artist:6lB8vOoI4DRrrVxXwuV19c'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ZRQcIgzPCVaT9XKhXZIzh'},
#    'followers': {'href': None, 'total': 907100},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'pop',
#     'pop dance',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/2ZRQcIgzPCVaT9XKhXZIzh',
#    'id': '2ZRQcIgzPCVaT9XKhXZIzh',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebe6def75adc302e270d220932',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174e6def75adc302e270d220932',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178e6def75adc302e270d220932',
#      'width': 160}],
#    'name': 'Gryffin',
#    'popularity': 73,
#    'type': 'artist',
#    'uri': 'spotify:artist:2ZRQcIgzPCVaT9XKhXZIzh'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ehtJnVumNf6xzSCDk8aLB'},
#    'followers': {'href': None, 'total': 1344646},
#    'genres': ['dance pop',
#     'danish electronic',
#     'edm',
#     'electro house',
#     'pop',
#     'pop dance',
#     'pop edm',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/4ehtJnVumNf6xzSCDk8aLB',
#    'id': '4ehtJnVumNf6xzSCDk8aLB',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebda1144fb20f96075198f3295',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174da1144fb20f96075198f3295',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178da1144fb20f96075198f3295',
#      'width': 160}],
#    'name': 'Martin Jensen',
#    'popularity': 69,
#    'type': 'artist',
#    'uri': 'spotify:artist:4ehtJnVumNf6xzSCDk8aLB'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1HBjj22wzbscIZ9sEb5dyf'},
#    'followers': {'href': None, 'total': 3755330},
#    'genres': ['dance pop',
#     'edm',
#     'pop',
#     'pop dance',
#     'tropical house',
#     'uk dance'],
#    'href': 'https://api.spotify.com/v1/artists/1HBjj22wzbscIZ9sEb5dyf',
#    'id': '1HBjj22wzbscIZ9sEb5dyf',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebbc95115e9bcbbec624bbf0e2',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174bc95115e9bcbbec624bbf0e2',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178bc95115e9bcbbec624bbf0e2',
#      'width': 160}],
#    'name': 'Jonas Blue',
#    'popularity': 77,
#    'type': 'artist',
#    'uri': 'spotify:artist:1HBjj22wzbscIZ9sEb5dyf'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#    'followers': {'href': None, 'total': 8310048},
#    'genres': ['edm', 'pop', 'pop dance', 'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#    'id': '23fqKkggKUBHNkbKtXEls4',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb85eca1ac80d81edbec725938',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517485eca1ac80d81edbec725938',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17885eca1ac80d81edbec725938',
#      'width': 160}],
#    'name': 'Kygo',
#    'popularity': 81,
#    'type': 'artist',
#    'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5CiGnKThu5ctn9pBxv7DGa'},
#    'followers': {'href': None, 'total': 1035528},
#    'genres': ['dance pop', 'edm', 'electropop', 'pop', 'pop rap'],
#    'href': 'https://api.spotify.com/v1/artists/5CiGnKThu5ctn9pBxv7DGa',
#    'id': '5CiGnKThu5ctn9pBxv7DGa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb860c37890942e05e58c19372',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174860c37890942e05e58c19372',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178860c37890942e05e58c19372',
#      'width': 160}],
#    'name': 'benny blanco',
#    'popularity': 75,
#    'type': 'artist',
#    'uri': 'spotify:artist:5CiGnKThu5ctn9pBxv7DGa'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hyEbRtp617pNCuuQjyOmc'},
#    'followers': {'href': None, 'total': 388190},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'pop',
#     'pop dance',
#     'pop edm',
#     'pop rap',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/3hyEbRtp617pNCuuQjyOmc',
#    'id': '3hyEbRtp617pNCuuQjyOmc',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb89a45083a99ce21831df7bdc',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517489a45083a99ce21831df7bdc',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17889a45083a99ce21831df7bdc',
#      'width': 160}],
#    'name': 'Lost Kings',
#    'popularity': 60,
#    'type': 'artist',
#    'uri': 'spotify:artist:3hyEbRtp617pNCuuQjyOmc'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4YXycRbyyAE0wozTk7QMEq'},
#    'followers': {'href': None, 'total': 728686},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'electropop',
#     'norwegian pop',
#     'pop',
#     'pop dance',
#     'pop edm',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/4YXycRbyyAE0wozTk7QMEq',
#    'id': '4YXycRbyyAE0wozTk7QMEq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb9e89c8d25b3f4b4be014f2a8',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051749e89c8d25b3f4b4be014f2a8',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1789e89c8d25b3f4b4be014f2a8',
#      'width': 160}],
#    'name': 'Matoma',
#    'popularity': 68,
#    'type': 'artist',
#    'uri': 'spotify:artist:4YXycRbyyAE0wozTk7QMEq'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#    'followers': {'href': None, 'total': 1358679},
#    'genres': ['edm', 'melodic dubstep', 'pop', 'pop dance', 'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#    'id': '45eNHdiiabvmbp4erw26rg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb81a0ab3a9a4326929a01b0f1',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517481a0ab3a9a4326929a01b0f1',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17881a0ab3a9a4326929a01b0f1',
#      'width': 160}],
#    'name': 'ILLENIUM',
#    'popularity': 75,
#    'type': 'artist',
#    'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1LOB7jTeEV14pHai6EXSzF'},
#    'followers': {'href': None, 'total': 677778},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'electropop',
#     'electropowerpop',
#     'pop',
#     'pop dance',
#     'pop edm',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/1LOB7jTeEV14pHai6EXSzF',
#    'id': '1LOB7jTeEV14pHai6EXSzF',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebc6b0d99b1a736712a1653d6a',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174c6b0d99b1a736712a1653d6a',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178c6b0d99b1a736712a1653d6a',
#      'width': 160}],
#    'name': 'Cash Cash',
#    'popularity': 65,
#    'type': 'artist',
#    'uri': 'spotify:artist:1LOB7jTeEV14pHai6EXSzF'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#    'followers': {'href': None, 'total': 1531617},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'pop',
#     'pop dance',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#    'id': '1IueXOQyABrMOprrzwQJWN',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb676cabffde9eb5b921355358',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174676cabffde9eb5b921355358',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178676cabffde9eb5b921355358',
#      'width': 160}],
#    'name': 'Sigala',
#    'popularity': 76,
#    'type': 'artist',
#    'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0pt7PX4Hftlg8mV1ySU84Q'},
#    'followers': {'href': None, 'total': 85735},
#    'genres': ['edm',
#     'electropop',
#     'pop',
#     'pop dance',
#     'pop edm',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/0pt7PX4Hftlg8mV1ySU84Q',
#    'id': '0pt7PX4Hftlg8mV1ySU84Q',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb77e0931f7e53b9ec6ed2a7af',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517477e0931f7e53b9ec6ed2a7af',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17877e0931f7e53b9ec6ed2a7af',
#      'width': 160}],
#    'name': 'CVBZ',
#    'popularity': 58,
#    'type': 'artist',
#    'uri': 'spotify:artist:0pt7PX4Hftlg8mV1ySU84Q'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5iNrZmtVMtYev5M9yoWpEq'},
#    'followers': {'href': None, 'total': 334851},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'norwegian pop',
#     'pop',
#     'pop dance',
#     'pop edm',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/5iNrZmtVMtYev5M9yoWpEq',
#    'id': '5iNrZmtVMtYev5M9yoWpEq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebc370fb6c5d9e9aac210acaac',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174c370fb6c5d9e9aac210acaac',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178c370fb6c5d9e9aac210acaac',
#      'width': 160}],
#    'name': 'Seeb',
#    'popularity': 70,
#    'type': 'artist',
#    'uri': 'spotify:artist:5iNrZmtVMtYev5M9yoWpEq'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/41rVuRHYAiH7ltBTHVR9We'},
#    'followers': {'href': None, 'total': 644580},
#    'genres': ['bass trap',
#     'brostep',
#     'edm',
#     'electro house',
#     'electronic trap',
#     'future bass',
#     'pop dance'],
#    'href': 'https://api.spotify.com/v1/artists/41rVuRHYAiH7ltBTHVR9We',
#    'id': '41rVuRHYAiH7ltBTHVR9We',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebc019e104e93b594a20fd6f9e',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174c019e104e93b594a20fd6f9e',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178c019e104e93b594a20fd6f9e',
#      'width': 160}],
#    'name': 'Slushii',
#    'popularity': 56,
#    'type': 'artist',
#    'uri': 'spotify:artist:41rVuRHYAiH7ltBTHVR9We'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5p7f24Rk5HkUZsaS3BLG5F'},
#    'followers': {'href': None, 'total': 8502423},
#    'genres': ['dance pop', 'pop', 'post-teen pop'],
#    'href': 'https://api.spotify.com/v1/artists/5p7f24Rk5HkUZsaS3BLG5F',
#    'id': '5p7f24Rk5HkUZsaS3BLG5F',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eba961383967f3a3a54e794a15',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174a961383967f3a3a54e794a15',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178a961383967f3a3a54e794a15',
#      'width': 160}],
#    'name': 'Hailee Steinfeld',
#    'popularity': 73,
#    'type': 'artist',
#    'uri': 'spotify:artist:5p7f24Rk5HkUZsaS3BLG5F'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LZ4De2MoO3lP6QaNCfvcu'},
#    'followers': {'href': None, 'total': 264491},
#    'genres': ['edm',
#     'electropop',
#     'future bass',
#     'melodic dubstep',
#     'pop dance',
#     'pop edm',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/4LZ4De2MoO3lP6QaNCfvcu',
#    'id': '4LZ4De2MoO3lP6QaNCfvcu',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebcd9e2b8f901285164a7fde6c',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174cd9e2b8f901285164a7fde6c',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178cd9e2b8f901285164a7fde6c',
#      'width': 160}],
#    'name': 'Said The Sky',
#    'popularity': 60,
#    'type': 'artist',
#    'uri': 'spotify:artist:4LZ4De2MoO3lP6QaNCfvcu'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5jAMCwdNHWr7JThxtMuEyy'},
#    'followers': {'href': None, 'total': 267942},
#    'genres': ['alt z',
#     'dance pop',
#     'edm',
#     'electro house',
#     'electropop',
#     'pop',
#     'pop dance',
#     'pop edm',
#     'post-teen pop',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/5jAMCwdNHWr7JThxtMuEyy',
#    'id': '5jAMCwdNHWr7JThxtMuEyy',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb5bf118575990892d7d6f747c',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051745bf118575990892d7d6f747c',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1785bf118575990892d7d6f747c',
#      'width': 160}],
#    'name': 'NOTD',
#    'popularity': 68,
#    'type': 'artist',
#    'uri': 'spotify:artist:5jAMCwdNHWr7JThxtMuEyy'}]}

# %%
key_list2 = res_01_dict.keys()
key_list2
# Out:
# dict_keys(['artists'])

# %%
len(res_01_dict['artists'])
# Out:
# 20

# %%
res_01_dict['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp'},
#   'followers': {'href': None, 'total': 20003183},
#   'genres': ['dance pop',
#    'edm',
#    'electropop',
#    'pop',
#    'pop dance',
#    'tropical house'],
#   'href': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp',
#   'id': '69GGBxA162lTqCwzJG5jLp',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb3c02f4fb4cc9187c488afd50',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051743c02f4fb4cc9187c488afd50',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1783c02f4fb4cc9187c488afd50',
#     'width': 160}],
#   'name': 'The Chainsmokers',
#   'popularity': 82,
#   'type': 'artist',
#   'uri': 'spotify:artist:69GGBxA162lTqCwzJG5jLp'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7DMveApC7UnC2NPfPvlHSU'},
#   'followers': {'href': None, 'total': 2159804},
#   'genres': ['dance pop',
#    'edm',
#    'electro house',
#    'electropop',
#    'pop',
#    'pop dance',
#    'post-teen pop',
#    'tropical house'],
#   'href': 'https://api.spotify.com/v1/artists/7DMveApC7UnC2NPfPvlHSU',
#   'id': '7DMveApC7UnC2NPfPvlHSU',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb6b4a14efca7b2fd8967390be',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051746b4a14efca7b2fd8967390be',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1786b4a14efca7b2fd8967390be',
#     'width': 160}],
#   'name': 'Cheat Codes',
#   'popularity': 72,
#   'type': 'artist',
#   'uri': 'spotify:artist:7DMveApC7UnC2NPfPvlHSU'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6t1gpxYbY8OlLA7D2RiikQ'},
#   'followers': {'href': None, 'total': 610536},
#   'genres': ['dance pop',
#    'edm',
#    'electro house',
#    'pop',
#    'pop dance',
#    'tropical house'],
#   'href': 'https://api.spotify.com/v1/artists/6t1gpxYbY8OlLA7D2RiikQ',
#   'id': '6t1gpxYbY8OlLA7D2RiikQ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eba4686c91d1b14b400725f95e',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174a4686c91d1b14b400725f95e',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178a4686c91d1b14b400725f95e',
#     'width': 160}],
#   'name': 'Loud Luxury',
#   'popularity': 72,
#   'type': 'artist',
#   'uri': 'spotify:artist:6t1gpxYbY8OlLA7D2RiikQ'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6lB8vOoI4DRrrVxXwuV19c'},
#   'followers': {'href': None, 'total': 1477986},
#   'genres': ['dance pop',
#    'edm',
#    'electro house',
#    'pop',
#    'pop dance',
#    'pop edm',
#    'swedish tropical house',
#    'tropical house'],
#   'href': 'https://api.spotify.com/v1/artists/6lB8vOoI4DRrrVxXwuV19c',
#   'id': '6lB8vOoI4DRrrVxXwuV19c',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb4ca7ccebc2f9e6c281cd6ff3',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051744ca7ccebc2f9e6c281cd6ff3',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1784ca7ccebc2f9e6c281cd6ff3',
#     'width': 160}],
#   'name': 'Mike Perry',
#   'popularity': 70,
#   'type': 'artist',
#   'uri': 'spotify:artist:6lB8vOoI4DRrrVxXwuV19c'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ZRQcIgzPCVaT9XKhXZIzh'},
#   'followers': {'href': None, 'total': 907100},
#   'genres': ['dance pop',
#    'edm',
#    'electro house',
#    'pop',
#    'pop dance',
#    'tropical house'],
#   'href': 'https://api.spotify.com/v1/artists/2ZRQcIgzPCVaT9XKhXZIzh',
#   'id': '2ZRQcIgzPCVaT9XKhXZIzh',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebe6def75adc302e270d220932',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174e6def75adc302e270d220932',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178e6def75adc302e270d220932',
#     'width': 160}],
#   'name': 'Gryffin',
#   'popularity': 73,
#   'type': 'artist',
#   'uri': 'spotify:artist:2ZRQcIgzPCVaT9XKhXZIzh'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ehtJnVumNf6xzSCDk8aLB'},
#   'followers': {'href': None, 'total': 1344646},
#   'genres': ['dance pop',
#    'danish electronic',
#    'edm',
#    'electro house',
#    'pop',
#    'pop dance',
#    'pop edm',
#    'tropical house'],
#   'href': 'https://api.spotify.com/v1/artists/4ehtJnVumNf6xzSCDk8aLB',
#   'id': '4ehtJnVumNf6xzSCDk8aLB',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebda1144fb20f96075198f3295',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174da1144fb20f96075198f3295',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178da1144fb20f96075198f3295',
#     'width': 160}],
#   'name': 'Martin Jensen',
#   'popularity': 69,
#   'type': 'artist',
#   'uri': 'spotify:artist:4ehtJnVumNf6xzSCDk8aLB'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1HBjj22wzbscIZ9sEb5dyf'},
#   'followers': {'href': None, 'total': 3755330},
#   'genres': ['dance pop',
#    'edm',
#    'pop',
#    'pop dance',
#    'tropical house',
#    'uk dance'],
#   'href': 'https://api.spotify.com/v1/artists/1HBjj22wzbscIZ9sEb5dyf',
#   'id': '1HBjj22wzbscIZ9sEb5dyf',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebbc95115e9bcbbec624bbf0e2',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174bc95115e9bcbbec624bbf0e2',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178bc95115e9bcbbec624bbf0e2',
#     'width': 160}],
#   'name': 'Jonas Blue',
#   'popularity': 77,
#   'type': 'artist',
#   'uri': 'spotify:artist:1HBjj22wzbscIZ9sEb5dyf'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#   'followers': {'href': None, 'total': 8310048},
#   'genres': ['edm', 'pop', 'pop dance', 'tropical house'],
#   'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#   'id': '23fqKkggKUBHNkbKtXEls4',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb85eca1ac80d81edbec725938',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517485eca1ac80d81edbec725938',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17885eca1ac80d81edbec725938',
#     'width': 160}],
#   'name': 'Kygo',
#   'popularity': 81,
#   'type': 'artist',
#   'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5CiGnKThu5ctn9pBxv7DGa'},
#   'followers': {'href': None, 'total': 1035528},
#   'genres': ['dance pop', 'edm', 'electropop', 'pop', 'pop rap'],
#   'href': 'https://api.spotify.com/v1/artists/5CiGnKThu5ctn9pBxv7DGa',
#   'id': '5CiGnKThu5ctn9pBxv7DGa',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb860c37890942e05e58c19372',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174860c37890942e05e58c19372',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178860c37890942e05e58c19372',
#     'width': 160}],
#   'name': 'benny blanco',
#   'popularity': 75,
#   'type': 'artist',
#   'uri': 'spotify:artist:5CiGnKThu5ctn9pBxv7DGa'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hyEbRtp617pNCuuQjyOmc'},
#   'followers': {'href': None, 'total': 388190},
#   'genres': ['dance pop',
#    'edm',
#    'electro house',
#    'pop',
#    'pop dance',
#    'pop edm',
#    'pop rap',
#    'tropical house'],
#   'href': 'https://api.spotify.com/v1/artists/3hyEbRtp617pNCuuQjyOmc',
#   'id': '3hyEbRtp617pNCuuQjyOmc',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb89a45083a99ce21831df7bdc',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517489a45083a99ce21831df7bdc',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17889a45083a99ce21831df7bdc',
#     'width': 160}],
#   'name': 'Lost Kings',
#   'popularity': 60,
#   'type': 'artist',
#   'uri': 'spotify:artist:3hyEbRtp617pNCuuQjyOmc'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4YXycRbyyAE0wozTk7QMEq'},
#   'followers': {'href': None, 'total': 728686},
#   'genres': ['dance pop',
#    'edm',
#    'electro house',
#    'electropop',
#    'norwegian pop',
#    'pop',
#    'pop dance',
#    'pop edm',
#    'tropical house'],
#   'href': 'https://api.spotify.com/v1/artists/4YXycRbyyAE0wozTk7QMEq',
#   'id': '4YXycRbyyAE0wozTk7QMEq',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb9e89c8d25b3f4b4be014f2a8',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051749e89c8d25b3f4b4be014f2a8',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1789e89c8d25b3f4b4be014f2a8',
#     'width': 160}],
#   'name': 'Matoma',
#   'popularity': 68,
#   'type': 'artist',
#   'uri': 'spotify:artist:4YXycRbyyAE0wozTk7QMEq'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#   'followers': {'href': None, 'total': 1358679},
#   'genres': ['edm', 'melodic dubstep', 'pop', 'pop dance', 'tropical house'],
#   'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#   'id': '45eNHdiiabvmbp4erw26rg',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb81a0ab3a9a4326929a01b0f1',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517481a0ab3a9a4326929a01b0f1',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17881a0ab3a9a4326929a01b0f1',
#     'width': 160}],
#   'name': 'ILLENIUM',
#   'popularity': 75,
#   'type': 'artist',
#   'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1LOB7jTeEV14pHai6EXSzF'},
#   'followers': {'href': None, 'total': 677778},
#   'genres': ['dance pop',
#    'edm',
#    'electro house',
#    'electropop',
#    'electropowerpop',
#    'pop',
#    'pop dance',
#    'pop edm',
#    'tropical house'],
#   'href': 'https://api.spotify.com/v1/artists/1LOB7jTeEV14pHai6EXSzF',
#   'id': '1LOB7jTeEV14pHai6EXSzF',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebc6b0d99b1a736712a1653d6a',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174c6b0d99b1a736712a1653d6a',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178c6b0d99b1a736712a1653d6a',
#     'width': 160}],
#   'name': 'Cash Cash',
#   'popularity': 65,
#   'type': 'artist',
#   'uri': 'spotify:artist:1LOB7jTeEV14pHai6EXSzF'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#   'followers': {'href': None, 'total': 1531617},
#   'genres': ['dance pop',
#    'edm',
#    'electro house',
#    'pop',
#    'pop dance',
#    'tropical house'],
#   'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#   'id': '1IueXOQyABrMOprrzwQJWN',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb676cabffde9eb5b921355358',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174676cabffde9eb5b921355358',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178676cabffde9eb5b921355358',
#     'width': 160}],
#   'name': 'Sigala',
#   'popularity': 76,
#   'type': 'artist',
#   'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0pt7PX4Hftlg8mV1ySU84Q'},
#   'followers': {'href': None, 'total': 85735},
#   'genres': ['edm',
#    'electropop',
#    'pop',
#    'pop dance',
#    'pop edm',
#    'tropical house'],
#   'href': 'https://api.spotify.com/v1/artists/0pt7PX4Hftlg8mV1ySU84Q',
#   'id': '0pt7PX4Hftlg8mV1ySU84Q',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb77e0931f7e53b9ec6ed2a7af',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517477e0931f7e53b9ec6ed2a7af',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17877e0931f7e53b9ec6ed2a7af',
#     'width': 160}],
#   'name': 'CVBZ',
#   'popularity': 58,
#   'type': 'artist',
#   'uri': 'spotify:artist:0pt7PX4Hftlg8mV1ySU84Q'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5iNrZmtVMtYev5M9yoWpEq'},
#   'followers': {'href': None, 'total': 334851},
#   'genres': ['dance pop',
#    'edm',
#    'electro house',
#    'norwegian pop',
#    'pop',
#    'pop dance',
#    'pop edm',
#    'tropical house'],
#   'href': 'https://api.spotify.com/v1/artists/5iNrZmtVMtYev5M9yoWpEq',
#   'id': '5iNrZmtVMtYev5M9yoWpEq',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebc370fb6c5d9e9aac210acaac',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174c370fb6c5d9e9aac210acaac',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178c370fb6c5d9e9aac210acaac',
#     'width': 160}],
#   'name': 'Seeb',
#   'popularity': 70,
#   'type': 'artist',
#   'uri': 'spotify:artist:5iNrZmtVMtYev5M9yoWpEq'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/41rVuRHYAiH7ltBTHVR9We'},
#   'followers': {'href': None, 'total': 644580},
#   'genres': ['bass trap',
#    'brostep',
#    'edm',
#    'electro house',
#    'electronic trap',
#    'future bass',
#    'pop dance'],
#   'href': 'https://api.spotify.com/v1/artists/41rVuRHYAiH7ltBTHVR9We',
#   'id': '41rVuRHYAiH7ltBTHVR9We',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebc019e104e93b594a20fd6f9e',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174c019e104e93b594a20fd6f9e',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178c019e104e93b594a20fd6f9e',
#     'width': 160}],
#   'name': 'Slushii',
#   'popularity': 56,
#   'type': 'artist',
#   'uri': 'spotify:artist:41rVuRHYAiH7ltBTHVR9We'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5p7f24Rk5HkUZsaS3BLG5F'},
#   'followers': {'href': None, 'total': 8502423},
#   'genres': ['dance pop', 'pop', 'post-teen pop'],
#   'href': 'https://api.spotify.com/v1/artists/5p7f24Rk5HkUZsaS3BLG5F',
#   'id': '5p7f24Rk5HkUZsaS3BLG5F',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eba961383967f3a3a54e794a15',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174a961383967f3a3a54e794a15',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178a961383967f3a3a54e794a15',
#     'width': 160}],
#   'name': 'Hailee Steinfeld',
#   'popularity': 73,
#   'type': 'artist',
#   'uri': 'spotify:artist:5p7f24Rk5HkUZsaS3BLG5F'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LZ4De2MoO3lP6QaNCfvcu'},
#   'followers': {'href': None, 'total': 264491},
#   'genres': ['edm',
#    'electropop',
#    'future bass',
#    'melodic dubstep',
#    'pop dance',
#    'pop edm',
#    'tropical house'],
#   'href': 'https://api.spotify.com/v1/artists/4LZ4De2MoO3lP6QaNCfvcu',
#   'id': '4LZ4De2MoO3lP6QaNCfvcu',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebcd9e2b8f901285164a7fde6c',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174cd9e2b8f901285164a7fde6c',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178cd9e2b8f901285164a7fde6c',
#     'width': 160}],
#   'name': 'Said The Sky',
#   'popularity': 60,
#   'type': 'artist',
#   'uri': 'spotify:artist:4LZ4De2MoO3lP6QaNCfvcu'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5jAMCwdNHWr7JThxtMuEyy'},
#   'followers': {'href': None, 'total': 267942},
#   'genres': ['alt z',
#    'dance pop',
#    'edm',
#    'electro house',
#    'electropop',
#    'pop',
#    'pop dance',
#    'pop edm',
#    'post-teen pop',
#    'tropical house'],
#   'href': 'https://api.spotify.com/v1/artists/5jAMCwdNHWr7JThxtMuEyy',
#   'id': '5jAMCwdNHWr7JThxtMuEyy',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb5bf118575990892d7d6f747c',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051745bf118575990892d7d6f747c',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1785bf118575990892d7d6f747c',
#     'width': 160}],
#   'name': 'NOTD',
#   'popularity': 68,
#   'type': 'artist',
#   'uri': 'spotify:artist:5jAMCwdNHWr7JThxtMuEyy'}]

# %%
res_01_dict['artists'][0]['name']
# Out:
# 'The Chainsmokers'

# %%
artists_list = [res_01_dict['artists'][artista]['name'] for artista in range(len(res_01_dict['artists']))]
artists_list
# Out:
# ['The Chainsmokers',
#  'Cheat Codes',
#  'Loud Luxury',
#  'Mike Perry',
#  'Gryffin',
#  'Martin Jensen',
#  'Jonas Blue',
#  'Kygo',
#  'benny blanco',
#  'Lost Kings',
#  'Matoma',
#  'ILLENIUM',
#  'Cash Cash',
#  'Sigala',
#  'CVBZ',
#  'Seeb',
#  'Slushii',
#  'Hailee Steinfeld',
#  'Said The Sky',
#  'NOTD']

# %%
full_endpoint_02 = full_endpoint + top_tracks + country
print(full_endpoint_02)

res_02 = requests.get(full_endpoint_02, headers=header_info)
res_02
# Out:
# https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T/top-tracks?country=us
# <Response [200]>

# %%
full_endpoint_03 = base_url + resource + '{}' + top_tracks + country
print(full_endpoint_03)

for artist in artists_list:
    response = requests.get(full_endpoint_03.format(artist), headers=header_info)
    print([response.json()['tracks'][track]['name'] for track in range(len(response.json()['tracks']))])
# Out:
# https://api.spotify.com/v1/artists/{}/top-tracks?country=us
# ['Something Just Like This', 'Closer', "Don't Let Me Down", 'Paris', 'Roses', 'Takeaway', 'This Feeling', 'Call You Mine', 'High', 'All We Know']
# ['Pretty Girl - Cheat Codes X CADE Remix', 'No Promises (feat. Demi Lovato)', 'I Remember', 'Never Love You Again', 'Sex', 'Bets On Us', 'South of the Border (feat. Camila Cabello & Cardi B) - Cheat Codes Remix', 'Shed a Light', 'Lean On Me', 'Something’s Coming']
# ['Body', 'These Nights', 'Sunroof - Loud Luxury Remix', 'Next To You (feat. Kane Brown)', 'Afterparty', 'Body - Dzeko Remix', 'Love No More', 'Body On My', "I'm Not Alright", 'Aftertaste']
# ['Dive', 'The Ocean (feat. Shy Martin)', 'By Your Side', "I Can't Love", 'Stay Young', 'Take It Slowly', 'I Like It', 'Told You So', 'If I Ruled The World', 'Changes']
# ['Woke Up in Love', 'Tie Me Down (with Elley Duhé)', 'Desire - Gryffin Remix', 'Body Back (feat. Maia Wright)', 'Feel Good (feat. Daya)', "Caught Up (with Olivia O'Brien)", 'You Were Loved (with OneRepublic)', 'Dreams', 'Forever (feat. Elley Duhé)', 'Best Is Yet To Come (with Kyle Reynolds)']
# ['Solo Dance', 'One Day', 'What a Night', 'At Least I Had Fun', "Don't Play Games", "Day 'N' Nite - Martin Jensen Edit", 'Nobody', 'Days Like This', "I'm Just Feelin' (Du Du Du)", 'Middle Of The Night']
# ['Weekends', 'Perfect Strangers', 'Fast Car', 'Don’t Wake Me Up', 'Mama', 'Rise', 'Ritual', 'Polaroid', 'Keeping Your Head Up - Jonas Blue Remix; Radio Edit [Radio Edit]', 'Crying On The Dancefloor']
# ['It Ain’t Me (with Selena Gomez)', 'Higher Love', 'Woke Up in Love', 'Firestone', 'Dancing Feet (feat. DNCE)', 'Lose Somebody', 'Stole the Show', 'Born To Be Yours', 'Lost Without You (with Dean Lewis)', "What's Love Got to Do with It"]
# ['Eastside (with Halsey & Khalid)', 'Bad Decisions (with BTS & Snoop Dogg)', 'Lonely (with benny blanco)', 'Graduation (with Juice WRLD)', 'Roses (with Juice WRLD feat. Brendon Urie)', 'Real Shit (with benny blanco)', 'I Can’t Get Enough (benny blanco, Selena Gomez, J Balvin, Tainy)', 'Unlearn (with Gracie Abrams)', 'You (with Marshmello & Vance Joy)', 'I Found You (with Calvin Harris)']
# ['Mountains', 'When We Were Young', 'Me Myself & Adderall', "Don't Kill My High", 'Broken In All The Right Places', 'I Do', 'Anti-Everything', 'I Miss The Future', 'Phone Down', "Oops (I'm Sorry)"]
# ['All Night', 'Good Vibes', 'Summer Feeling', 'Easy To Love', 'Old Thing Back (feat. Ja Rule and Ralph Tresvant)', 'All Night - Slowed N Reverb', 'Take Me To The Sunshine (feat. BullySongs)', 'False Alarm', 'Easy To Love - Armin van Buuren Club Mix', 'Beside You (feat. Georgia Ku)']
# ['Takeaway', 'Luv Me A Little', 'Good Things Fall Apart (with Jon Bellion)', 'Insanity', 'Don’t Let Me Let Go (with ILLENIUM & EVAN GIIA)', 'Feel Good (feat. Daya)', 'All That Really Matters', 'Story Of My Life (feat. Trippie Redd)', 'Feel Something (With I Prevail)', "Don't Let Me Down (feat. Daya) - Illenium Remix"]
# ['Hero (feat. Christina Perri)', 'Take Me Home (feat. Bebe Rexha)', 'Can We Pretend (feat. Cash Cash)', 'I Found You', 'Take Me Home (feat. Bebe Rexha) - Acoustic', 'What About Us - Cash Cash Remix', '42 (feat. J.Lauryn)', 'How to Love (feat. Sofia Reyes)', 'Ride or Die (feat. Phoebe Ryan)', 'Finest Hour (feat. Abir)']
# ['All By Myself', 'Melody', 'Stay the Night', 'Feels This Good', 'Lasting Lover', 'Radio', 'You for Me', 'Living Without You', "Sweet Lovin' - Radio Edit", 'Came Here for Love']
# ['Feels Great (feat. Fetty Wap & CVBZ)', "Don't Call Me", 'Love Better', '2 Gone', 'Be Somebody', 'This Time is Right', 'Me and My Girl and All Of Our Drugs', 'Neverender', 'Louder', 'Forever Love']
# ['I Took A Pill In Ibiza - Seeb Remix', 'Hymn for the Weekend - Seeb Remix', 'Rich Love (with Seeb)', 'Delicate - Seeb Remix', 'Bigger Than', 'Easier - Seeb Remix', 'Submarine', 'Would You Lie', 'Breathe', 'Atlantis']
# ['PEW PEW', 'All I Need', 'LUV U NEED U', 'Sober', 'Side To Side - Slushii Remix', 'So Long (feat. Madi)', 'Silence - Slushii Remix', 'Test Me', 'All I Need - VIP', 'Valhalla']
# ['Let Me Go (with Alesso, Florida Georgia Line & watt)', 'Coast (feat. Anderson .Paak)', 'Starving', 'Love Myself', 'Most Girls', 'Capital Letters', 'Rock Bottom', 'Wrong Direction', 'Flashlight (Sweet Life Mix) - From "Pitch Perfect 2" Soundtrack', 'Woke Up Late (feat. Hailee Steinfeld)']
# ['Picture', 'Good Things Fall Apart vs. Sad Songs (With Said The Sky feat. Annika Wells)', 'Walk Me Home', 'Rush Over Me', 'Emotion Sickness', 'Potions', "Where'd U Go", 'Sad Songs (& Said The Sky with Annika Wells)', 'Go on Then, Love', 'All I Got']
# ['So Close', 'Keep You Mine', "I Don't Know Why", 'I Wanna Know (feat. Bea Miller)', 'Never A Good Time', 'Malibu', 'Beautiful People (feat. Khalid) - NOTD Remix', 'Worst Thing', "There's Nothing Holdin' Me Back - NOTD Remix", 'Nobody']

# %% [markdown]
# ---
#
# ### Bonus track!!!
#
# You can publish your own Playlist with [`/playlists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/create-playlist) and [`/tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/add-tracks-to-playlist).
#
# ![I quit](https://media.giphy.com/media/gui67fZ3xIneM/giphy.gif)

# %%
# Bonus

# %% [markdown]
# ---

# %% [markdown]
# You can always try with the [wrapper](https://github.com/plamere/spotipy)!!!
#
# ![I quit](https://media.giphy.com/media/3oFzlXPvXYZ4q8VQOs/giphy.gif)

# %% [markdown]
# ---
